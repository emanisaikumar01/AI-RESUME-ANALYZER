# %% [markdown]
# # Benchmark Tests for AI Resume Analyzer
#
# This notebook contains simple tests for the skill gap and job match agents.

# %%
from agents.skill_gap_agent import compute_skill_gaps
from agents.job_match_agent import score_job_match

current = ['python', 'react', 'sql']
target = ['python', 'react', 'sql', 'docker', 'kubernetes']
gaps = compute_skill_gaps(current, target)
gaps

resume_skills = ['python', 'react', 'sql']
job_skills = ['python', 'django', 'sql']
score_job_match(resume_skills, job_skills)

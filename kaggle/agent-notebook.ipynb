# %% [markdown]
# # AI Resume Analyzer Agent Notebook
#
# This notebook demonstrates how to use the Python agents from the `agents/` folder
# to analyze resume text with Gemini and compute skill gaps.

# %%
import os
from agents.resume_agent import analyze_resume_text
from agents.skill_gap_agent import compute_skill_gaps

# Configure your Gemini key in the environment
os.environ['GEMINI_API_KEY'] = 'YOUR_KEY_HERE'  # or set via Kaggle Secrets

sample_resume = '''
John Doe is a software engineer with experience in Python, React, SQL and cloud.
He has built APIs, dashboards and worked with machine learning workflows.
'''

analysis = analyze_resume_text(sample_resume)
analysis
